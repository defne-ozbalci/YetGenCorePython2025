# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

import time
import random

class Kumanda():
    def __init__(self,durum="Kapalı",ses=0,kanal_sayi=0,kanal_liste=["Trt"],kanal="Trt"):
        self.durum=durum
        self.ses=ses
        self.kanal_sayi=kanal_sayi
        self.kanal_liste=kanal_liste
        self.kanal=kanal
    
    def tv_ac(self):
        if self.durum == "Açık":
            print("Televizyon zaten açık....")
        else:
            print("Televizyon açılıyor....")
            time.sleep(1)
            print("Açıldı")
            self.durum = "Açık"
    def tv_kapat(self):
        if self.durum == "Kapalı":
            print("Televizyon zaten kapalı....")
        else:
            print("Televizyon kapatılıyor....")
            time.sleep(1)
            print("Kapatıldı")
            self.durum = "Kapalı"
    
    def ses_ayarla(self):
        while True:
            ses_secim = input("Sesi azalt: '<'\n Sesi yükselt: '>'\n Çıkış yap: çıkış")
            if ses_secim == "<":
                if self.ses != 0:
                    self.ses -= 1
                    print("Ses: ", self.ses)
            elif ses_secim == ">":
                if self.ses != 20:
                    self.ses += 1
                    print("Ses: ", self.ses)
            else:
                print("Ses güncellendi: ", self.ses)
                break

    def tv_kanal_ekle(self,kanal_ismi):
        print("Kanal ekleniyor....")
        time.sleep(1)
        self.kanal_liste.append(kanal_ismi)
        print(f"{kanal_ismi} kanalı listeye eklendi")
    def rastgele_kanal(self):
        rastgele=random.randint(0,len(self.kanal_liste)-1)
        # randint (aralık başı,aralık sonu+1)
        self.kanal=self.kanal_liste[rastgele]
        print("Şuanki kanal: ", self.kanal)
    def __len__(self):
        return len(self.kanal_liste)
    
    def __str__(self):
        return "{} \nSes Yüksekliği: {}\nKanal Listesi: {}\nSeçili Kanal: {}\n".format(self.durum,self.ses,self.kanal_liste,self.kanal)
    
kumanda=Kumanda()

print("""
Televizyon Uygulaması
1.Televizyonu Açma
2.Televizyonu Kapatma
3.Ses Ayarları
4.Kanal Ekleme
5.Kanal Sayısı Öğrenme
6.Rastgele Kanal seçimi
7.Televizyon Bilgileri

Çıkmak için 'q' ya basınız.""")

while True:
    islem=input("Yapmak istediğiniz işlemi seçiniz: ")
    if islem=="q":
        print("Program sonlandırıldı.")
        break
    elif islem=="1":
        kumanda.tv_ac()
    elif islem=="2":
        kumanda.tv_kapat()
    elif islem=="3":
        kumanda.ses_ayarla()
    elif islem=="4":
        yeni_kanal=input("Eklemek istenilen kanal isimlarini arasına ',' işareti koyarak giriniz: ")
        kanal_listesi=yeni_kanal.split(",")
        for i in kanal_listesi:
            kumanda.tv_kanal_ekle(i)
    elif islem=="5":
        print("Toplam kanal sayısı: ",len(kumanda))
    elif islem=="6":
        kumanda.rastgele_kanal()
    elif islem=="7":
        print(kumanda)
    else:
        print("Geçersiz işlem!")
# Out:
# Televizyon Uygulaması
# 1.Televizyonu Açma
# 2.Televizyonu Kapatma
# 3.Ses Ayarları
# 4.Kanal Ekleme
# 5.Kanal Sayısı Öğrenme
# 6.Rastgele Kanal seçimi
# 7.Televizyon Bilgileri
#
# Çıkmak için 'q' ya basınız.
# Televizyon açılıyor....
# Açıldı
# Televizyon kapatılıyor....
# Kapatıldı
# Televizyon zaten kapalı....
# Televizyon açılıyor....
# Açıldı
# Ses:  1
# Ses:  2
# Ses:  3
# Ses:  4
# Ses:  5
# Ses:  4
# Ses:  3
# Ses güncellendi:  3
# Kanal ekleniyor....
# National_Geography kanalı listeye eklendi
# Kanal ekleniyor....
# BBC_news kanalı listeye eklendi
# Kanal ekleniyor....
# now_hd kanalı listeye eklendi
# Toplam kanal sayısı:  4
# Toplam kanal sayısı:  4
# Şuanki kanal:  BBC_news
# Şuanki kanal:  BBC_news
# Şuanki kanal:  now_hd
# Şuanki kanal:  BBC_news
# Açık
# Ses Yüksekliği: 3
# Kanal Listesi: ['Trt', 'National_Geography', 'BBC_news', 'now_hd']
# Seçili Kanal: BBC_news
#
# Program sonlandırıldı.
